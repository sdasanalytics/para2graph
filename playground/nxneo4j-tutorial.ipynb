# %% [markdown]
# # Welcome to nxneo4j!
# #### nxneo4j is a library that enables you to use networkX type of commands to interact with Neo4j.

# %% [markdown]
# Check out the following Mediumn article before you begin:
#
# - https://medium.com/neo4j/nxneo4j-networkx-api-for-neo4j-a-new-chapter-9fc65ddab222
# - https://github.com/ybaktir/networkx-neo4j

# %% [markdown]
# ### _Latest version is 0.0.3_
# If not already installed, install the latest version like this:

# %%
# ! pip uninstall -y networkx-neo4j #remove the old installation

# %%
# ! pip install git+https://github.com/ybaktir/networkx-neo4j

# %%
import datetime, time
print ('Last run on: ' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S") + ' ' + repr(time.tzname))
# Out:
# Last run on: 2021-12-10 19:25:24 ('IST', 'IST')

# %% [markdown]
# ## Connect to Neo4j

# %% [markdown]
# Open a free Sandbox session at sandbox.neo4j.com:
#
# https://sandbox.neo4j.com/
#
# Get the connections details like the following

# %%
user = 'neo4j'
# password = '84KCr8fxUP5h8nmx8NdIrZIBR5mmrFaIoGoZTkesq5U' # Aura Free password
# uri = 'neo4j+s://01141c89.databases.neo4j.io' # Aura Free URI
password = "unonothing"
uri = "bolt://localhost:7687"

from neo4j import GraphDatabase
import nxneo4j as nx
driver = GraphDatabase.driver(uri=uri,auth=(user,password))
                              #OR "bolt://localhost:7673" for Neo4j Desktop
                              #OR the cloud url
G = nx.Graph(driver)

# %% [markdown]
# ## Add Nodes

# %% [markdown]
# ```
# #Add a node
# G.add_node("Yusuf")
#
# #Add node with features
# G.add_node("Nurgul",gender='F')
#
# #Add multiple properties at once
# G.add_node("Betul",age=4,gender='F')
#
# #Check nodes
# for node in G.nodes():   #Unlike networkX, nxneo4j returns a generator
#     print(node)
#
# #Or simply
# list(G.nodes())
#
# #Get the data associated with each node
# list(G.nodes(data=True))
#
# #number of nodes
# len(G)
#
# #Check a particular node feature
# G.nodes['Betul']
#
# #You can be more specific
# G.nodes['Betul']['age']
# ```

# %% [markdown]
# ## Add Edges

# %% [markdown]
# ```
# #Add one edge
# G.add_edge('Yusuf','Betul')
#
# #You can change the default connection label like the following
# G.relationship_type = 'LOVES'
# G.add_edge('Yusuf','Nurgul')
# G.add_edge('Nurgul','Yusuf')
#
# #You can add properties as well
# G.add_edge('Betul','Nurgul',how_much='More than Dad')
#
# #display the values
# list(G.edges(data=True))
#
# G.relationship_type = 'CONNECTED'
#
# G.add_edges_from([(1,2),(3,4)])
# ```

# %% [markdown]
# ## Remove Nodes

# %% [markdown]
# ```
# G.remove_node('Yusuf')
#
# list(G.nodes())
# ```

# %% [markdown]
# ## Graph Data Science

# %% [markdown]
# There are several builtin graph algorithms in Neo4j. nxneo4j will expand to cover all of them in the future versions. For now, the following networkX algorithms are supported:
# - pagerank
# - betweenness_centrality
# - closeness_centrality
# - label_propagation
# - connected_components
# - clustering
# - triangles
# - shortest_path
# - shortest_weighted_path
#
# Let's delete all data and load GOT data:

# %%
# G.delete_all()
# G.load_got()

#You can change the default parameters like the following:

# G.identifier_property = 'name'
# G.relationship_type = '*'
# G.node_label = 'Character'

# %%
len(G) #796 nodes
# Out:
# 359

# %%
# nx.draw(G)

# %% [markdown]
# ## 1. Centrality Algorithms

# %% [markdown]
# We’ll start with the famous PageRank algorithm. Let’s find out who the most influential characters in Game of Thrones are:

# %% [markdown]
# ### Pagerank

# %% [markdown]
# We’ll start with the famous PageRank algorithm. Let’s find out who the most influential characters in Game of Thrones are:

# %%
nx.pagerank(G) #RAW OUTPUT
# Out:
# {'Baby One More Time': 3.1819176563922804,
#  'a song': 0.8795088963450438,
#  'Britney Spears': 1.79201436124696,
#  'single': 0.4204630007933438,
#  'song': 3.068471761156469,
#  'release': 0.4204630007933438,
#  'Work': 1.2509600764878221,
#  'WrittenWork': 0.920305566416573,
#  'PeriodicalLiterature': 0.920305566416573,
#  'human': 2.7896433304770185,
#  'person': 2.383359269447412,
#  'natural person': 2.383359269447412,
#  'Person': 2.3064925553929085,
#  'Agent': 2.5669540475390162,
#  'Artist': 0.8512196487066803,
#  'Baby': 0.8578674141585692,
#  'demographic profile': 0.5145935844943342,
#  'One': 1.7527149041232508,
#  'power of 10': 0.5224518838646621,
#  'centered triangular number': 0.5224518838646621,
#  'centered pentagonal number': 0.5224518838646621,
#  'Time': 2.6868284202716843,
#  'online magazine': 0.6742390932198294,
#  'print news magazine': 0.6742390932198294,
#  'magazine': 0.6742390932198294,
#  'periodical': 0.6498425656232297,
#  'communication medium': 0.40375600735369294,
#  'literary form': 0.4398001080344472,
#  'type of musical work/composition': 0.4398001080344472,
#  'genre': 1.0533498345823438,
#  'class': 1.4187103585377,
#  'collection_of_musical_notes': 0.4398001080344472,
#  'composition_of_music': 0.4398001080344472,
#  'music': 0.7142829973086761,
#  'Britney': 1.5755785265325384,
#  'album': 2.9062896056963416,
#  'Spears': 0.5730947595685796,
#  'family name': 1.194583435301427,
#  'Diwali': 3.3095024529033408,
#  'generally a time': 3.6175016840413816,
#  'visits': 2.6815499430151384,
#  'exchanging gifts': 0.7765183478978258,
#  'wearing new clothes': 0.7230676627522008,
#  'attending feasts': 1.0152707974437412,
#  'feeding the poor': 0.4295342136256524,
#  'lighting fireworks': 0.7601887236969014,
#  'holiday': 0.6506322921154948,
#  'festival': 2.5906312409507852,
#  'recurring event': 0.38442308446635665,
#  'Holiday': 0.6506322921154948,
#  'time': 3.81858483217766,
#  'abstract_concept': 0.42048308586613625,
#  'arbatrary': 0.42048308586613625,
#  'constant': 0.42048308586613625,
#  'scholarly article': 0.529886215484821,
#  'Wikimedia list article': 0.529886215484821,
#  'going': 0.529886215484821,
#  'social_activity': 0.529886215484821,
#  'meeting': 0.529886215484821,
#  'gifts': 2.449299827598513,
#  'literary work': 0.49698413427217386,
#  'object': 0.49698413427217386,
#  'present': 0.49698413427217386,
#  'software': 0.49698413427217386,
#  'clothes': 1.3813338782425832,
#  'feasts': 1.1126595320202193,
#  'thing': 0.46525349795195253,
#  'fireworks': 1.556021377090032,
#  'MusicalWork': 0.480654510071249,
#  'low_explosive': 0.480654510071249,
#  'new clothes': 0.7230676627522008,
#  'the Festival': 0.9335982410025707,
#  'Lights': 1.598029490405457,
#  'Festival': 0.7468673811708932,
#  'form of event': 0.7819952358144834,
#  'people': 3.40974057616403,
#  'light lamps': 1.0184572204945435,
#  'their homes': 0.9547623658011074,
#  'worship Godess Lakshmi': 1.1874166263012433,
#  'organisms known by a particular common name': 0.6376098413480389,
#  'counting unit': 0.6376098413480389,
#  'alcoholics': 0.6376098413480389,
#  'alergic_to_fur': 0.6376098413480389,
#  'alergic_to_wheat': 0.6376098413480389,
#  'lamps': 1.7922231863980966,
#  'light': 0.5308473791465048,
#  'electrical_device': 0.5308473791465048,
#  'source_of_illumination': 0.5308473791465048,
#  'homes': 1.865603278988359,
#  'castle': 0.46715252445306876,
#  'comfortable_place_to_live': 0.46715252445306876,
#  'house': 0.46715252445306876,
#  'Godess': 0.829472812762463,
#  'painting': 0.5025258401139505,
#  'Lakshmi': 2.08885718772705,
#  'Devi': 0.34728094483925287,
#  'love deity': 0.34728094483925287,
#  'wealth deity': 0.34728094483925287,
#  'brand new clothes': 1.1056572881565083,
#  'brand': 3.6860308525134053,
#  'second-order class': 0.5416407531638235,
#  'first-order metaclass': 0.5416407531638235,
#  'fixed-order metaclass': 0.5416407531638235,
#  '(meta)class': 0.5416407531638235,
#  'mountain': 0.5416407531638235,
#  'kind': 0.5416407531638235,
#  'marker': 0.5416407531638235,
#  'extremely expensive clothes': 0.7140165349926849,
#  'Donald Trump': 1.9148613280830873,
#  'the worst president': 0.8644647891476117,
#  'USA': 3.535534185701005,
#  'federal republic': 0.8593923377815796,
#  'superpower': 0.6261433379022889,
#  'constitutional republic': 0.8593923377815796,
#  'sovereign state': 0.942585349243424,
#  'democratic republic': 0.3811695358280188,
#  'PopulatedPlace': 1.9023320959113184,
#  'Place': 1.6414521266816162,
#  'Country': 0.614418535707309,
#  'Donald': 0.7417105832115237,
#  'male given name': 0.8757504028866803,
#  'Trump': 1.294547047198408,
#  'president': 1.885482780073215,
#  'position': 1.0259826372478953,
#  'elected_official': 0.4705320443127015,
#  'goat_sucker': 0.4705320443127015,
#  'head_of_government': 0.4705320443127015,
#  'Hillary Clinton': 1.607525835813806,
#  'is better than Donald Trump': 0.8509090705936831,
#  'Hillary': 0.7905494547704802,
#  'Clinton': 0.47887939764199183,
#  'is better than him': 0.3207996094279686,
#  'Gujratis': 2.2587182404756407,
#  'a shopping spree': 1.330591550347167,
#  'ethnic group': 0.4242729243758002,
#  'social group': 0.8622468801906057,
#  'group of humans': 0.4242729243758002,
#  'EthnicGroup': 0.4242729243758002,
#  'shopping': 2.7852262920859765,
#  'industry': 0.48820604530194894,
#  'activity': 0.8147953428928643,
#  'action': 0.8147953428928643,
#  'tiring': 0.48820604530194894,
#  'buying_activity': 0.48820604530194894,
#  'buying': 0.48820604530194894,
#  'spree': 2.689558957995114,
#  'river': 0.4765892975909154,
#  'occupation': 0.8210123003091065,
#  'human activity': 0.4765892975909154,
#  'intemperance': 0.4765892975909154,
#  'IBM': 3.370678279460246,
#  'a very large company': 0.9544449722649619,
#  'public company': 0.7232754364369427,
#  'software company': 0.7232754364369427,
#  'business': 0.41046149214610717,
#  'enterprise': 0.41046149214610717,
#  'Organisation': 0.41046149214610717,
#  'Company': 0.41046149214610717,
#  'company': 3.3121477173813907,
#  'legal form': 0.46281394429083594,
#  'type of organisation': 0.46281394429083594,
#  'capitalist_institution': 0.46281394429083594,
#  'legal_entity': 0.46281394429083594,
#  'organization': 0.46281394429083594,
#  'that': 1.5776367288168422,
#  'headquarters': 0.6416310279741259,
#  'It': 1.908583485865763,
#  'India': 2.744105999532679,
#  'country': 0.7114158134154053,
#  'dominion of the British Empire': 0.3832489998792904,
#  'We': 1.6375853073499866,
#  'celebrate this festival': 0.8125634929785652,
#  'great fervour': 0.9517630249275586,
#  'social': 0.464576635476314,
#  'celebration': 0.464576635476314,
#  'time_period': 0.464576635476314,
#  'fervour': 1.0677087920844228,
#  'Mitzvah': 0.6037761674253086,
#  'also the New Year': 1.5608592353874524,
#  'the New Year': 3.131873110032427,
#  'musical ensemble': 0.416209207649138,
#  'public holiday': 0.416209207649138,
#  'non-working day': 0.416209207649138,
#  'New': 1.878295860345467,
#  'modern language': 0.46931027358223504,
#  'definitely endangered language': 0.46931027358223504,
#  'language': 0.46931027358223504,
#  'Year': 1.878295860345467,
#  'unit of time': 0.46931027358223504,
#  'unit without standard conversion to SI': 0.46931027358223504,
#  'UCUM derived unit': 0.46931027358223504,
#  'Retailers': 2.836934265350792,
#  'this festival': 0.8090615014755718,
#  'economic branch': 0.4944848659992575,
#  'system': 0.4944848659992575,
#  'structure': 0.4944848659992575,
#  'distributor': 0.4944848659992575,
#  'merchant': 0.4944848659992575,
#  'the windward side': 1.110998088187425,
#  'very big island': 0.7929495621456424,
#  'island': 3.088628914076866,
#  'island nation': 0.4781668135361154,
#  'RecordLabel': 0.4781668135361154,
#  'another_name_for_roundabout': 0.4781668135361154,
#  'body_of_land': 0.4781668135361154,
#  'completely': 0.4781668135361154,
#  'side': 3.230195791982051,
#  'component': 0.5422380365908003,
#  'perceptible object': 0.5422380365908003,
#  'physical object': 0.5422380365908003,
#  'physical_surface': 0.5422380365908003,
#  'surface': 0.5422380365908003,
#  'aspect': 0.5422380365908003,
#  'had rocks': 0.8285285760598814,
#  'eastern shore': 0.8285285760598814,
#  'shore': 1.9309664895017145,
#  'at_sea_level': 0.5603303461249772,
#  'beam': 0.5603303461249772,
#  'geological_formation': 0.5603303461249772,
#  'rocks': 1.9309664895017145,
#  'genre_of_music': 0.5603303461249772,
#  'hard': 0.5603303461249772,
#  'inanimate_object': 0.5603303461249772,
#  'Justin': 1.1984111140179823,
#  'a fight': 0.9039172601181111,
#  ' unnecessarily': 0.48954979242927366,
#  'fight': 3.4124380920571245,
#  'boxing match': 0.5643674676888365,
#  'sporting event': 0.5643674676888365,
#  'entertainment event': 0.5643674676888365,
#  'conflict': 0.5643674676888365,
#  'dangerous_activity': 0.5643674676888365,
#  'irreflexive_action': 0.5643674676888365,
#  'Manoj Das': 1.9730052876074389,
#  'brother': 2.736193081289471,
#  'Rinku Das': 0.9959902453104728,
#  'Manoj': 1.0355845234254242,
#  'Das': 0.7832023282497069,
#  'kinship': 0.5879739558148057,
#  'social relation': 0.5879739558148057,
#  "another_son_of_one's_own_parents": 0.36143309279710145,
#  'big_goof': 0.36143309279710145,
#  'family_relationship_term': 0.36143309279710145,
#  'Rinku': 0.9541669484278245,
#  'big brother': 0.7407864489954825,
#  'is daughter': 0.9414135742555471,
#  'Tina': 0.8520290827842617,
#  'female given name': 0.5121122690418404,
#  'daughter': 2.13214951048283,
#  'child': 0.3765408630177041,
#  'female_offspring': 0.3765408630177041,
#  'Mortgage renewal process': 2.151541741155294,
#  'end': 2.836424815032721,
#  'term': 2.430714288820354,
#  'Mortgage': 1.9607346846192857,
#  'authorized_agreement': 0.5666560914107576,
#  'secured_loan': 0.5666560914107576,
#  'written_loan_contract': 0.5666560914107576,
#  'renewal': 2.8982482528472646,
#  'occurrence': 0.5605851497728025,
#  'redevelopment': 0.5605851497728025,
#  'urban planning': 0.5605851497728025,
#  'construction': 0.5605851497728025,
#  'repetition': 0.5605851497728025,
#  'process': 1.9607346846192857,
#  'projection_from_bone': 0.5666560914107576,
#  'series_of_steps_taken': 0.5666560914107576,
#  'physical_entity': 0.5666560914107576,
#  'American football position': 0.4944230027181918,
#  'contribution': 0.4944230027181918,
#  'lineman': 0.4944230027181918,
#  'piece_of_cloth': 0.4944230027181918,
#  'register': 0.5632214058427877,
#  'unit_of_time': 0.5632214058427877,
#  'indeterminate_term': 0.5632214058427877,
#  'quantity': 0.5632214058427877,
#  'Mumbai': 3.069176147233732,
#  'the capital': 0.9267305504806002,
#  'Maharashtra': 2.2034725267060096,
#  'megacity': 0.41087996922970094,
#  'big city': 0.7109329201970459,
#  'million city': 0.41087996922970094,
#  'state capital': 0.6591660389571816,
#  'city': 0.6591660389571816,
#  'City': 0.41087996922970094,
#  'Settlement': 0.9267305504806002,
#  'state of India': 0.4175645115234178,
#  'states and union territories of India': 0.4175645115234178,
#  'federated state': 0.4175645115234178,
#  'capital': 2.6289114053923677,
#  'largely': 0.39828606972748076,
#  'principle_to_capitalism': 0.39828606972748076,
#  'the financial capital': 0.8924150388364722,
#  'there': 1.1597222761158756,
#  'Once upon a time': 0.7490710422599732,
#  'three bears': 1.6114504356044959,
#  'bears': 4.298359231029326,
#  'American football team': 0.515360523955357,
#  'taxon': 0.515360523955357,
#  'group of living things': 0.515360523955357,
#  'Animal': 0.515360523955357,
#  'Eukaryote': 0.515360523955357,
#  'Species': 0.515360523955357,
#  'carnivore': 0.515360523955357,
#  'mammal': 0.515360523955357,
#  'who': 0.8210211643086198,
#  ' were married': 0.49243320791478246,
#  'People': 4.053190371498244,
#  'text': 0.39608655826953665,
#  'publication': 0.39608655826953665,
#  'The US President': 0.7765474380193512,
#  'Joe Biden': 1.805781800699474,
#  'US': 2.5938403690271947,
#  'album chart': 0.39497380207427013,
#  'record chart': 0.39497380207427013,
#  'ranked list': 0.39497380207427013,
#  'President': 0.9930711437080045,
#  'Joe': 0.9245594529104901,
#  'Han surname': 0.4119584526943392,
#  'Biden': 1.3325393391697176,
#  'Thriller': 1.4285672041530066,
#  'a hit album': 2.0689941596905945,
#  'Michael Jackson': 2.0623558148608208,
#  '1984': 1.802143344120075,
#  'fiction genre': 0.4535704935035328,
#  'leap year starting on Sunday and ending on Monday': 0.5329554192196088,
#  'calendar year': 0.5329554192196088,
#  'leap year': 0.5329554192196088,
#  'hit': 4.547836915564434,
#  'ministry-owned university': 0.5365661212606142,
#  'vice-ministerial level university': 0.5365661212606142,
#  'university': 0.5365661212606142,
#  'sports terminology': 0.5365661212606142,
#  'specialized terminology': 0.5365661212606142,
#  'human communication': 0.5365661212606142,
#  'joining': 0.5365661212606142,
#  'murder': 0.5365661212606142,
#  'success': 0.5365661212606142,
#  'music release type': 0.424482889274229,
#  'music term': 0.424482889274229,
#  'technical term': 0.424482889274229,
#  'collection': 0.424482889274229,
#  'Michael': 1.5875086765602109,
#  'archangel': 0.4873455263237712,
#  'angel in Judaism': 0.4873455263237712,
#  'Mukarrabun': 0.4873455263237712,
#  'Jackson': 1.4120140521529632,
#  'city of the United States': 0.4500529509673447,
#  'state or insular area capital in the United States': 0.4500529509673447,
#  'early 1984': 0.4431074878286501,
#  'have a working prototype': 0.8079660905466143,
#  'a rocket': 0.9279085126369643,
#  'prototype': 2.1880887038425643,
#  'model': 0.4599792330443634,
#  'video_game': 0.4599792330443634,
#  'rocket': 2.023160870463505,
#  'artifact': 0.5799216551347123,
#  'faster_than_aeroplane': 0.5799216551347123,
#  'machine': 0.5799216551347123}

# %%
# the most influential characters
response = nx.pagerank(G)
sorted_pagerank = sorted(response.items(), key=lambda x: x[1], reverse=True)
for character, score in sorted_pagerank[:10]:
    print(character, score)
# Out:
# hit 4.547836915564434
# bears 4.298359231029326
# People 4.053190371498244
# time 3.81858483217766
# brand 3.6860308525134053
# generally a time 3.6175016840413816
# USA 3.535534185701005
# fight 3.4124380920571245
# people 3.40974057616403
# IBM 3.370678279460246

# %% [markdown]
# ### Betweenness centrality

# %% [markdown]
# We can also run betweenness centrality over the dataset. This algorithm will tell us which nodes are the most 'pivotal' i.e. how many of the shortest paths between pairs of characters must pass through them

# %%
# Betweenness centrality
nx.betweenness_centrality(G) #RAW OUTPUT
# Out:
# {' unnecessarily': 0.0,
#  ' were married': 0.0,
#  '(meta)class': 0.0,
#  '1984': 1068.0,
#  'Agent': 7551.820161206322,
#  'American football position': 0.0,
#  'American football team': 0.0,
#  'Animal': 0.0,
#  'Artist': 674.2339757018091,
#  'Baby': 357.0,
#  'Baby One More Time': 4814.8920033820805,
#  'Biden': 1634.72012605214,
#  'Britney': 1529.5264813254832,
#  'Britney Spears': 3607.6006543376,
#  'City': 0.0,
#  'Clinton': 0.0,
#  'Company': 0.0,
#  'Country': 104.21972037937964,
#  'Das': 240.0698273432797,
#  'Devi': 0.0,
#  'Diwali': 21063.220192717505,
#  'Donald': 586.1402255639094,
#  'Donald Trump': 1915.4397583657908,
#  'EthnicGroup': 0.0,
#  'Eukaryote': 0.0,
#  'Festival': 16.84825174825174,
#  'Godess': 357.0,
#  'Gujratis': 4408.565053837859,
#  'Han surname': 0.0,
#  'Hillary': 0.23076923076923078,
#  'Hillary Clinton': 430.46953969840735,
#  'Holiday': 437.58009721272924,
#  'IBM': 5738.205459496755,
#  'India': 5638.34270311193,
#  'It': 7957.511940262792,
#  'Jackson': 1592.7166048657236,
#  'Joe': 625.1376053985568,
#  'Joe Biden': 3130.9318512276477,
#  'Justin': 3149.0,
#  'Lakshmi': 2634.3108819275853,
#  'Lights': 9341.867883811612,
#  'Maharashtra': 1264.0890185541282,
#  'Manoj': 3220.9613770001947,
#  'Manoj Das': 1082.6823602696368,
#  'Michael': 1068.0,
#  'Michael Jackson': 8126.991797600441,
#  'Mitzvah': 0.0,
#  'Mortgage': 1068.0,
#  'Mortgage renewal process': 6575.0,
#  'Mukarrabun': 0.0,
#  'Mumbai': 2131.5380484383722,
#  'MusicalWork': 0.0,
#  'New': 1068.0,
#  'Once upon a time': 1816.2945758709714,
#  'One': 1068.0,
#  'Organisation': 0.0,
#  'People': 3243.9304007801456,
#  'PeriodicalLiterature': 433.08577445057244,
#  'Person': 3309.5963266124418,
#  'Place': 2155.118296620969,
#  'PopulatedPlace': 3405.9304981868218,
#  'President': 3747.3464358348683,
#  'RecordLabel': 0.0,
#  'Retailers': 1872.0105894105895,
#  'Rinku': 376.91517504235037,
#  'Rinku Das': 54.60798302574618,
#  'Settlement': 48.01944444444441,
#  'Spears': 219.73981619280346,
#  'Species': 0.0,
#  'The US President': 1079.0244781228287,
#  'Thriller': 1991.944781192265,
#  'Time': 1895.7663747385984,
#  'Tina': 357.0,
#  'Trump': 117.23356058671054,
#  'UCUM derived unit': 0.0,
#  'US': 1774.666170459101,
#  'USA': 6894.674644254039,
#  'We': 3192.6325326629835,
#  'Wikimedia list article': 0.0,
#  'Work': 1095.7882207226164,
#  'WrittenWork': 433.08577445057244,
#  'Year': 1068.0,
#  'a fight': 2457.0,
#  'a hit album': 6605.742853938229,
#  'a rocket': 1416.0,
#  'a shopping spree': 6939.378060939499,
#  'a song': 2977.4789684838715,
#  'a very large company': 2275.3102285987957,
#  'abstract_concept': 0.0,
#  'action': 60.1351351351352,
#  'activity': 60.1351351351352,
#  'album': 1831.439364539536,
#  'album chart': 0.0,
#  'alcoholics': 203.39953962581598,
#  'alergic_to_fur': 203.39953962581598,
#  'alergic_to_wheat': 203.39953962581598,
#  'also the New Year': 2449.800000229646,
#  'angel in Judaism': 0.0,
#  'another_name_for_roundabout': 0.0,
#  "another_son_of_one's_own_parents": 0.0,
#  'arbatrary': 0.0,
#  'archangel': 0.0,
#  'artifact': 0.0,
#  'aspect': 0.0,
#  'at_sea_level': 0.0,
#  'attending feasts': 50.669108669108674,
#  'authorized_agreement': 0.0,
#  'beam': 0.0,
#  'bears': 3260.360839762586,
#  'big brother': 3.1500000000000004,
#  'big city': 857.4827707260062,
#  'big_goof': 0.0,
#  'body_of_land': 0.0,
#  'boxing match': 0.0,
#  'brand': 2478.0,
#  'brand new clothes': 2893.677026618269,
#  'brother': 2069.635184472755,
#  'business': 0.0,
#  'buying': 0.0,
#  'buying_activity': 0.0,
#  'calendar year': 0.0,
#  'capital': 1329.2899069485902,
#  'capitalist_institution': 0.0,
#  'carnivore': 0.0,
#  'castle': 0.0,
#  'celebrate this festival': 2694.379735460187,
#  'celebration': 0.0,
#  'centered pentagonal number': 0.0,
#  'centered triangular number': 0.0,
#  'child': 0.0,
#  'city': 12.932142857142857,
#  'city of the United States': 0.0,
#  'class': 3542.768563736245,
#  'clothes': 25.0,
#  'collection': 0.0,
#  'collection_of_musical_notes': 0.0,
#  'comfortable_place_to_live': 0.0,
#  'communication medium': 0.0,
#  'company': 3477.9875473667976,
#  'completely': 0.0,
#  'component': 0.0,
#  'composition_of_music': 0.0,
#  'conflict': 0.0,
#  'constant': 0.0,
#  'constitutional republic': 300.0540535562914,
#  'construction': 0.0,
#  'contribution': 0.0,
#  'counting unit': 203.39953962581598,
#  'country': 461.77764443159174,
#  'dangerous_activity': 0.0,
#  'daughter': 1952.1021496346884,
#  'definitely endangered language': 0.0,
#  'democratic republic': 0.0,
#  'demographic profile': 0.0,
#  'distributor': 0.0,
#  'dominion of the British Empire': 0.0,
#  'early 1984': 0.0,
#  'eastern shore': 1416.0,
#  'economic branch': 0.0,
#  'elected_official': 0.0,
#  'electrical_device': 0.0,
#  'end': 8339.541986155236,
#  'enterprise': 0.0,
#  'entertainment event': 0.0,
#  'ethnic group': 0.0,
#  'exchanging gifts': 0.0,
#  'extremely expensive clothes': 93.67702661826982,
#  'family name': 679.9115346489261,
#  'family_relationship_term': 0.0,
#  'faster_than_aeroplane': 0.0,
#  'feasts': 357.0,
#  'federal republic': 300.0540535562914,
#  'federated state': 0.0,
#  'feeding the poor': 0.0,
#  'female given name': 0.0,
#  'female_offspring': 0.0,
#  'fervour': 357.0,
#  'festival': 4491.839725470178,
#  'fiction genre': 0.0,
#  'fight': 2127.0,
#  'fireworks': 861.4794550246431,
#  'first-order metaclass': 0.0,
#  'fixed-order metaclass': 0.0,
#  'form of event': 23.000000000000007,
#  'generally a time': 6866.528365039007,
#  'genre': 846.6576893574266,
#  'genre_of_music': 0.0,
#  'geological_formation': 0.0,
#  'gifts': 1422.0,
#  'goat_sucker': 0.0,
#  'going': 0.0,
#  'great fervour': 712.0,
#  'group of humans': 0.0,
#  'group of living things': 0.0,
#  'had rocks': 1416.0,
#  'hard': 0.0,
#  'have a working prototype': 1033.1945403920981,
#  'head_of_government': 0.0,
#  'headquarters': 0.0,
#  'hit': 3177.0,
#  'holiday': 437.58009721272924,
#  'homes': 1365.9122178546074,
#  'house': 0.0,
#  'human': 4193.362212656749,
#  'human activity': 0.0,
#  'human communication': 0.0,
#  'inanimate_object': 0.0,
#  'indeterminate_term': 0.0,
#  'industry': 0.0,
#  'intemperance': 0.0,
#  'irreflexive_action': 0.0,
#  'is better than Donald Trump': 9.033333333333335,
#  'is better than him': 0.0,
#  'is daughter': 719.5351966873707,
#  'island': 1873.180688755686,
#  'island nation': 0.0,
#  'joining': 0.0,
#  'kind': 0.0,
#  'kinship': 5.042857142857142,
#  'lamps': 1068.0,
#  'language': 0.0,
#  'largely': 0.0,
#  'leap year': 0.0,
#  'leap year starting on Sunday and ending on Monday': 0.0,
#  'legal form': 0.0,
#  'legal_entity': 0.0,
#  'light': 0.0,
#  'light lamps': 1619.3995396258183,
#  'lighting fireworks': 624.1995341199538,
#  'lineman': 0.0,
#  'literary form': 0.0,
#  'literary work': 0.0,
#  'love deity': 0.0,
#  'low_explosive': 0.0,
#  'machine': 0.0,
#  'magazine': 512.4114920129155,
#  'male given name': 3481.870833333334,
#  'mammal': 0.0,
#  'marker': 0.0,
#  'meeting': 0.0,
#  'megacity': 0.0,
#  'merchant': 0.0,
#  'million city': 0.0,
#  'ministry-owned university': 0.0,
#  'model': 0.0,
#  'modern language': 0.0,
#  'mountain': 0.0,
#  'murder': 0.0,
#  'music': 365.72652625152597,
#  'music release type': 0.0,
#  'music term': 0.0,
#  'musical ensemble': 0.0,
#  'natural person': 3255.78326370716,
#  'new clothes': 79.3229733817302,
#  'non-working day': 0.0,
#  'object': 0.0,
#  'occupation': 3538.5805507334903,
#  'occurrence': 0.0,
#  'online magazine': 512.4114920129155,
#  'organisms known by a particular common name': 203.39953962581598,
#  'organization': 0.0,
#  'painting': 0.0,
#  'people': 10664.962564108222,
#  'perceptible object': 0.0,
#  'periodical': 53.46901154685809,
#  'person': 3255.78326370716,
#  'physical object': 0.0,
#  'physical_entity': 0.0,
#  'physical_surface': 0.0,
#  'piece_of_cloth': 0.0,
#  'position': 5139.397221197966,
#  'power of 10': 0.0,
#  'present': 0.0,
#  'president': 2566.997809172623,
#  'principle_to_capitalism': 0.0,
#  'print news magazine': 512.4114920129155,
#  'process': 1068.0,
#  'projection_from_bone': 0.0,
#  'prototype': 3144.376311955755,
#  'public company': 432.6364615818073,
#  'public holiday': 0.0,
#  'publication': 0.0,
#  'quantity': 0.0,
#  'ranked list': 0.0,
#  'record chart': 0.0,
#  'recurring event': 0.0,
#  'redevelopment': 0.0,
#  'register': 0.0,
#  'release': 0.0,
#  'renewal': 1775.0,
#  'repetition': 0.0,
#  'river': 0.0,
#  'rocket': 1068.0,
#  'rocks': 1068.0,
#  'scholarly article': 0.0,
#  'second-order class': 0.0,
#  'secured_loan': 0.0,
#  'series_of_steps_taken': 0.0,
#  'shopping': 1733.593776353516,
#  'shore': 1068.0,
#  'side': 2127.0,
#  'single': 0.0,
#  'social': 0.0,
#  'social group': 1015.5182220883298,
#  'social relation': 5.042857142857142,
#  'social_activity': 0.0,
#  'software': 0.0,
#  'software company': 432.6364615818073,
#  'song': 3832.345618118659,
#  'source_of_illumination': 0.0,
#  'sovereign state': 1657.3963910771006,
#  'specialized terminology': 0.0,
#  'sporting event': 0.0,
#  'sports terminology': 0.0,
#  'spree': 4990.332174149623,
#  'state capital': 12.932142857142857,
#  'state of India': 0.0,
#  'state or insular area capital in the United States': 0.0,
#  'states and union territories of India': 0.0,
#  'structure': 0.0,
#  'success': 0.0,
#  'superpower': 50.64290986790986,
#  'surface': 0.0,
#  'system': 0.0,
#  'taxon': 0.0,
#  'technical term': 0.0,
#  'term': 1422.0,
#  'text': 0.0,
#  'that': 4966.154001561734,
#  'the Festival': 348.84825174825187,
#  'the New Year': 2270.5929773694634,
#  'the capital': 48.01944444444441,
#  'the financial capital': 671.5522167159488,
#  'the windward side': 2843.5993894993894,
#  'the worst president': 3291.756545847803,
#  'their homes': 1403.647517203794,
#  'there': 1553.2588615852587,
#  'thing': 0.0,
#  'this festival': 116.47999999999999,
#  'three bears': 1368.8289022744968,
#  'time': 8565.207622702377,
#  'time_period': 0.0,
#  'tiring': 0.0,
#  'type of musical work/composition': 0.0,
#  'type of organisation': 0.0,
#  'unit of time': 0.0,
#  'unit without standard conversion to SI': 0.0,
#  'unit_of_time': 0.0,
#  'university': 0.0,
#  'urban planning': 0.0,
#  'very big island': 180.72637362637366,
#  'vice-ministerial level university': 0.0,
#  'video_game': 0.0,
#  'visits': 1775.0,
#  'wealth deity': 0.0,
#  'wearing new clothes': 79.3229733817302,
#  'who': 0.0,
#  'worship Godess Lakshmi': 2406.3327053342077,
#  'written_loan_contract': 0.0}

# %%
# RANKED OUTPUT
response = nx.betweenness_centrality(G)

sorted_bw = sorted(response.items(), key=lambda x: x[1], reverse=True)
for character, score in sorted_bw[:10]:
    print(character, score)
# Out:
# Diwali 21063.2201927175
# people 10664.962564108222
# Lights 9341.867883811612
# time 8565.207622702375
# end 8339.541986155236
# Michael Jackson 8126.991797600441
# It 7957.5119402627915
# Agent 7551.820161206323
# a shopping spree 6939.3780609395
# USA 6894.67464425404

# %% [markdown]
# ### Closeness centrality
#
# Closeness centrality tells us on average how many hops away each character is from every other character.

# %%
# Closeness centrality
nx.closeness_centrality(G) #RAW OUTPUT
# Out:
# {' unnecessarily': 0.12574639971900245,
#  ' were married': 0.12891609650702196,
#  '(meta)class': 0.13137614678899082,
#  '1984': 0.15674255691768826,
#  'Agent': 0.24026845637583893,
#  'American football position': 0.13570887035633056,
#  'American football team': 0.13166605369621184,
#  'Animal': 0.13166605369621184,
#  'Artist': 0.20801859384079024,
#  'Baby': 0.15279556124626548,
#  'Baby One More Time': 0.18008048289738432,
#  'Biden': 0.20562894887995406,
#  'Britney': 0.20515759312320916,
#  'Britney Spears': 0.20850320326150262,
#  'City': 0.1512463033375581,
#  'Clinton': 0.1881240147136101,
#  'Company': 0.17971887550200802,
#  'Country': 0.1967032967032967,
#  'Das': 0.1725301204819277,
#  'Devi': 0.17236398651901783,
#  'Diwali': 0.24470266575529734,
#  'Donald': 0.17344961240310078,
#  'Donald Trump': 0.20681686886192951,
#  'EthnicGroup': 0.17549019607843136,
#  'Eukaryote': 0.13166605369621184,
#  'Festival': 0.17063870352716873,
#  'Godess': 0.17523250122369066,
#  'Gujratis': 0.21271538918597743,
#  'Han surname': 0.15131022823330514,
#  'Hillary': 0.1883219358232509,
#  'Hillary Clinton': 0.19361817198485667,
#  'Holiday': 0.20387243735763097,
#  'IBM': 0.21896024464831804,
#  'India': 0.21233689205219455,
#  'It': 0.23368146214099217,
#  'Jackson': 0.17846460618145563,
#  'Joe': 0.17819810851169737,
#  'Joe Biden': 0.21009389671361503,
#  'Justin': 0.14377510040160643,
#  'Lakshmi': 0.20813953488372092,
#  'Lights': 0.23645970937912814,
#  'Maharashtra': 0.17186749879980798,
#  'Manoj': 0.19393282773564463,
#  'Manoj Das': 0.2028328611898017,
#  'Michael': 0.1735336888027145,
#  'Michael Jackson': 0.2091121495327103,
#  'Mitzvah': 0.10825521620804354,
#  'Mortgage': 0.12131480853947814,
#  'Mortgage renewal process': 0.1376923076923077,
#  'Mukarrabun': 0.14793388429752066,
#  'Mumbai': 0.1781094527363184,
#  'MusicalWork': 0.14044723420949393,
#  'New': 0.175146771037182,
#  'Once upon a time': 0.17891054472763618,
#  'One': 0.15305686190679776,
#  'Organisation': 0.17971887550200802,
#  'People': 0.18704284221525602,
#  'PeriodicalLiterature': 0.17195004803073968,
#  'Person': 0.22992935131663456,
#  'Place': 0.20410490307867732,
#  'PopulatedPlace': 0.20598388952819333,
#  'President': 0.18472652218782248,
#  'RecordLabel': 0.1443548387096774,
#  'Retailers': 0.18616744669786792,
#  'Rinku': 0.1924731182795699,
#  'Rinku Das': 0.17178502879078694,
#  'Settlement': 0.1522756273925989,
#  'Spears': 0.17696490360850223,
#  'Species': 0.13166605369621184,
#  'The US President': 0.1855883877656817,
#  'Thriller': 0.1669776119402985,
#  'Time': 0.17454900048756705,
#  'Tina': 0.1457654723127036,
#  'Trump': 0.19768083931529543,
#  'UCUM derived unit': 0.14910453977509372,
#  'US': 0.18733647305075876,
#  'USA': 0.21683827983040582,
#  'We': 0.15967885816235505,
#  'Wikimedia list article': 0.1476897689768977,
#  'Work': 0.17412451361867703,
#  'WrittenWork': 0.17195004803073968,
#  'Year': 0.175146771037182,
#  'a fight': 0.1263678079774091,
#  'a hit album': 0.18520434557682358,
#  'a rocket': 0.1381705905055963,
#  'a shopping spree': 0.19659527732015375,
#  'a song': 0.18763102725366876,
#  'a very large company': 0.1955215729109776,
#  'abstract_concept': 0.17506112469437654,
#  'action': 0.1463614063777596,
#  'activity': 0.1463614063777596,
#  'album': 0.18246687054026503,
#  'album chart': 0.15784832451499117,
#  'alcoholics': 0.19042553191489361,
#  'alergic_to_fur': 0.19042553191489361,
#  'alergic_to_wheat': 0.19042553191489361,
#  'also the New Year': 0.20387243735763097,
#  'angel in Judaism': 0.14793388429752066,
#  'another_name_for_roundabout': 0.1443548387096774,
#  "another_son_of_one's_own_parents": 0.16926713947990543,
#  'arbatrary': 0.17506112469437654,
#  'archangel': 0.14793388429752066,
#  'artifact': 0.10851773264625644,
#  'aspect': 0.13978914486528699,
#  'at_sea_level': 0.13288789903489234,
#  'attending feasts': 0.17714002968827314,
#  'authorized_agreement': 0.10822249093107618,
#  'beam': 0.13288789903489234,
#  'bears': 0.15156646909398813,
#  'big brother': 0.17186749879980798,
#  'big city': 0.16776007497656983,
#  'big_goof': 0.16926713947990543,
#  'body_of_land': 0.1443548387096774,
#  'boxing match': 0.10127298444130127,
#  'brand': 0.15118243243243243,
#  'brand new clothes': 0.17679012345679013,
#  'brother': 0.2036405005688282,
#  'business': 0.17971887550200802,
#  'buying': 0.14189456995640112,
#  'buying_activity': 0.14189456995640112,
#  'calendar year': 0.13555471412343809,
#  'capital': 0.1721981721981722,
#  'capitalist_institution': 0.14947807933194154,
#  'carnivore': 0.13166605369621184,
#  'castle': 0.14744645799011533,
#  'celebrate this festival': 0.175146771037182,
#  'celebration': 0.16870876531573986,
#  'centered pentagonal number': 0.1327893175074184,
#  'centered triangular number': 0.1327893175074184,
#  'child': 0.16736792893875643,
#  'city': 0.15175922000847816,
#  'city of the United States': 0.15150232754972492,
#  'class': 0.16635687732342008,
#  'clothes': 0.15195246179966043,
#  'collection': 0.154376886589047,
#  'collection_of_musical_notes': 0.14916666666666667,
#  'comfortable_place_to_live': 0.14744645799011533,
#  'communication medium': 0.14867109634551495,
#  'company': 0.17566241413150147,
#  'completely': 0.1443548387096774,
#  'component': 0.13978914486528699,
#  'composition_of_music': 0.14916666666666667,
#  'conflict': 0.10127298444130127,
#  'constant': 0.17506112469437654,
#  'constitutional republic': 0.1984478935698448,
#  'construction': 0.10835351089588378,
#  'contribution': 0.13570887035633056,
#  'counting unit': 0.19042553191489361,
#  'country': 0.17714002968827314,
#  'dangerous_activity': 0.10127298444130127,
#  'daughter': 0.20089786756453423,
#  'definitely endangered language': 0.14910453977509372,
#  'democratic republic': 0.17828685258964144,
#  'demographic profile': 0.1325925925925926,
#  'distributor': 0.1570175438596491,
#  'dominion of the British Empire': 0.17523250122369066,
#  'early 1984': 0.15633187772925763,
#  'eastern shore': 0.18026183282980865,
#  'economic branch': 0.1570175438596491,
#  'elected_official': 0.14793388429752066,
#  'electrical_device': 0.1387596899224806,
#  'end': 0.1569487067075844,
#  'enterprise': 0.17971887550200802,
#  'entertainment event': 0.10127298444130127,
#  'ethnic group': 0.17549019607843136,
#  'exchanging gifts': 0.17277992277992277,
#  'extremely expensive clothes': 0.17540421362077413,
#  'family name': 0.1724470134874759,
#  'family_relationship_term': 0.16926713947990543,
#  'faster_than_aeroplane': 0.10851773264625644,
#  'feasts': 0.1726133076181292,
#  'federal republic': 0.1984478935698448,
#  'federated state': 0.14672131147540984,
#  'feeding the poor': 0.17236398651901783,
#  'female given name': 0.12726626377532882,
#  'female_offspring': 0.16736792893875643,
#  'fervour': 0.12135593220338983,
#  'festival': 0.2028328611898017,
#  'fiction genre': 0.14314274290283888,
#  'fight': 0.11264946507237256,
#  'fireworks': 0.1633211678832117,
#  'first-order metaclass': 0.13137614678899082,
#  'fixed-order metaclass': 0.13137614678899082,
#  'form of event': 0.16894761680037754,
#  'generally a time': 0.20813953488372092,
#  'genre': 0.16422018348623854,
#  'genre_of_music': 0.13288789903489234,
#  'geological_formation': 0.13288789903489234,
#  'gifts': 0.17311411992263057,
#  'goat_sucker': 0.14793388429752066,
#  'going': 0.1476897689768977,
#  'great fervour': 0.13795761078998073,
#  'group of humans': 0.17549019607843136,
#  'group of living things': 0.13166605369621184,
#  'had rocks': 0.18026183282980865,
#  'hard': 0.13288789903489234,
#  'have a working prototype': 0.15578764142732812,
#  'head_of_government': 0.14793388429752066,
#  'headquarters': 0.18782791185729275,
#  'hit': 0.15757042253521128,
#  'holiday': 0.20387243735763097,
#  'homes': 0.17286335103814582,
#  'house': 0.14744645799011533,
#  'human': 0.2308188265635074,
#  'human activity': 0.1457654723127036,
#  'human communication': 0.13617344998098135,
#  'inanimate_object': 0.13288789903489234,
#  'indeterminate_term': 0.10828796128251664,
#  'industry': 0.14189456995640112,
#  'intemperance': 0.1457654723127036,
#  'irreflexive_action': 0.10127298444130127,
#  'is better than Donald Trump': 0.17286335103814582,
#  'is better than him': 0.16228467815049863,
#  'is daughter': 0.1703950499762018,
#  'island': 0.16862929816297692,
#  'island nation': 0.1443548387096774,
#  'joining': 0.13617344998098135,
#  'kind': 0.13137614678899082,
#  'kinship': 0.17023300047551118,
#  'lamps': 0.16104363472784525,
#  'language': 0.14910453977509372,
#  'largely': 0.1469622331691297,
#  'leap year': 0.13555471412343809,
#  'leap year starting on Sunday and ending on Monday': 0.13555471412343809,
#  'legal form': 0.14947807933194154,
#  'legal_entity': 0.14947807933194154,
#  'light': 0.1387596899224806,
#  'light lamps': 0.19123931623931623,
#  'lighting fireworks': 0.1774913237481408,
#  'lineman': 0.13570887035633056,
#  'literary form': 0.14916666666666667,
#  'literary work': 0.14762886597938144,
#  'love deity': 0.17236398651901783,
#  'low_explosive': 0.14044723420949393,
#  'machine': 0.10851773264625644,
#  'magazine': 0.1821882951653944,
#  'male given name': 0.16643421664342167,
#  'mammal': 0.13166605369621184,
#  'marker': 0.13137614678899082,
#  'meeting': 0.1476897689768977,
#  'megacity': 0.1512463033375581,
#  'merchant': 0.1570175438596491,
#  'million city': 0.1512463033375581,
#  'ministry-owned university': 0.13617344998098135,
#  'model': 0.14365971107544143,
#  'modern language': 0.14910453977509372,
#  'mountain': 0.13137614678899082,
#  'murder': 0.13617344998098135,
#  'music': 0.1665891112145184,
#  'music release type': 0.154376886589047,
#  'music term': 0.154376886589047,
#  'musical ensemble': 0.1602506714413608,
#  'natural person': 0.22992935131663456,
#  'new clothes': 0.17336561743341405,
#  'non-working day': 0.1602506714413608,
#  'object': 0.14762886597938144,
#  'occupation': 0.1559233449477352,
#  'occurrence': 0.10835351089588378,
#  'online magazine': 0.1821882951653944,
#  'organisms known by a particular common name': 0.19042553191489361,
#  'organization': 0.14947807933194154,
#  'painting': 0.14916666666666667,
#  'people': 0.22417031934877896,
#  'perceptible object': 0.13978914486528699,
#  'periodical': 0.16597125637459434,
#  'person': 0.22992935131663456,
#  'physical object': 0.13978914486528699,
#  'physical_entity': 0.10822249093107618,
#  'physical_surface': 0.13978914486528699,
#  'piece_of_cloth': 0.13570887035633056,
#  'position': 0.16721158337225595,
#  'power of 10': 0.1327893175074184,
#  'present': 0.14762886597938144,
#  'president': 0.1735336888027145,
#  'principle_to_capitalism': 0.1469622331691297,
#  'print news magazine': 0.1821882951653944,
#  'process': 0.12131480853947814,
#  'projection_from_bone': 0.10822249093107618,
#  'prototype': 0.16768149882903982,
#  'public company': 0.18675013041210226,
#  'public holiday': 0.1602506714413608,
#  'publication': 0.1576398062527521,
#  'quantity': 0.10828796128251664,
#  'ranked list': 0.15784832451499117,
#  'record chart': 0.15784832451499117,
#  'recurring event': 0.1967032967032967,
#  'redevelopment': 0.10835351089588378,
#  'register': 0.10828796128251664,
#  'release': 0.15266524520255864,
#  'renewal': 0.12147947064811673,
#  'repetition': 0.10835351089588378,
#  'river': 0.1457654723127036,
#  'rocket': 0.12168592794017676,
#  'rocks': 0.15318784766795038,
#  'scholarly article': 0.1476897689768977,
#  'second-order class': 0.13137614678899082,
#  'secured_loan': 0.10822249093107618,
#  'series_of_steps_taken': 0.10822249093107618,
#  'shopping': 0.16528162511542013,
#  'shore': 0.15318784766795038,
#  'side': 0.16243194192377494,
#  'single': 0.15266524520255864,
#  'social': 0.16870876531573986,
#  'social group': 0.19911012235817574,
#  'social relation': 0.17023300047551118,
#  'social_activity': 0.1476897689768977,
#  'software': 0.14762886597938144,
#  'software company': 0.18675013041210226,
#  'song': 0.17523250122369066,
#  'source_of_illumination': 0.1387596899224806,
#  'sovereign state': 0.19911012235817574,
#  'specialized terminology': 0.13617344998098135,
#  'sporting event': 0.10127298444130127,
#  'sports terminology': 0.13617344998098135,
#  'spree': 0.17055740828966173,
#  'state capital': 0.15175922000847816,
#  'state of India': 0.14672131147540984,
#  'state or insular area capital in the United States': 0.15150232754972492,
#  'states and union territories of India': 0.14672131147540984,
#  'structure': 0.1570175438596491,
#  'success': 0.13617344998098135,
#  'superpower': 0.17971887550200802,
#  'surface': 0.13978914486528699,
#  'system': 0.1570175438596491,
#  'taxon': 0.13166605369621184,
#  'technical term': 0.154376886589047,
#  'term': 0.12139708375720583,
#  'text': 0.1576398062527521,
#  'that': 0.21869273060476482,
#  'the Festival': 0.20294784580498867,
#  'the New Year': 0.19072988811933936,
#  'the capital': 0.1522756273925989,
#  'the financial capital': 0.1798994974874372,
#  'the windward side': 0.19257665411511565,
#  'the worst president': 0.19922092376182526,
#  'their homes': 0.1930960086299892,
#  'there': 0.15889924545051043,
#  'thing': 0.14726450020567666,
#  'this festival': 0.17540421362077413,
#  'three bears': 0.14793388429752066,
#  'time': 0.21208530805687204,
#  'time_period': 0.16870876531573986,
#  'tiring': 0.14189456995640112,
#  'type of musical work/composition': 0.14916666666666667,
#  'type of organisation': 0.14947807933194154,
#  'unit of time': 0.14910453977509372,
#  'unit without standard conversion to SI': 0.14910453977509372,
#  'unit_of_time': 0.10828796128251664,
#  'university': 0.13617344998098135,
#  'urban planning': 0.10835351089588378,
#  'very big island': 0.16651162790697674,
#  'vice-ministerial level university': 0.13617344998098135,
#  'video_game': 0.14365971107544143,
#  'visits': 0.17319787131107886,
#  'wealth deity': 0.17236398651901783,
#  'wearing new clothes': 0.17336561743341405,
#  'who': 0.1417260490894695,
#  'worship Godess Lakshmi': 0.21208530805687204,
#  'written_loan_contract': 0.10822249093107618}

# %%
# RANKED
response = nx.closeness_centrality(G)

sorted_cc = sorted(response.items(), key=lambda x: x[1], reverse=True)
for character, score in sorted_cc[:10]:
    print(character, score)
# Out:
# Diwali 0.24470266575529734
# Agent 0.24026845637583893
# Lights 0.23645970937912814
# It 0.23368146214099217
# human 0.2308188265635074
# Person 0.22992935131663456
# natural person 0.22992935131663456
# person 0.22992935131663456
# people 0.22417031934877896
# IBM 0.21896024464831804

# %% [markdown]
# ## 2. Community Detection Algoritms

# %% [markdown]
# ### Label Propagation
# We can also partition the characters into communities using the label propagation algorithm

# %%
# Label propagation
nx.label_propagation_communities(G) #RAW OUPUT is a generator
# Out:
# <generator object label_propagation_communities at 0x104d87820>

# %%
communities = nx.label_propagation_communities(G)
sorted_communities = sorted(communities, key=lambda x: len(x), reverse=True)
for community in sorted_communities[:10]:
    print(list(community)[:10])
# Out:
# ['collection', 'Country', 'marker', 'composition_of_music', 'goat_sucker', 'shore', 'social relation', 'castle', 'model', 'irreflexive_action']
# ['alergic_to_fur', 'time_period', 'merchant', 'It', 'electrical_device', 'side', 'thing', 'river', 'musical ensemble', 'people']
# ['process', 'series_of_steps_taken', 'secured_loan', 'written_loan_contract', 'quantity', 'Mortgage renewal process', 'repetition', 'construction', 'unit_of_time', 'authorized_agreement']
# ['a rocket', 'rocket', 'fervour', 'Mitzvah', 'machine', 'great fervour', 'We', 'faster_than_aeroplane', 'artifact']
# [' were married', 'who', 'three bears', 'there']

# %% [markdown]
# Characters are in the same community as those other characters with whom they frequently interact. The idea is that characters have closer ties to those in their community than to those outside.

# %% [markdown]
# ### Clustering
# We can calculate the clustering coefficient for each character. A clustering coefficient of '1' means that all characters that interact with that character also interact with each other:

# %%
# Clustering
nx.clustering(G) #RAW OUTPUT
# Out:
# {'exchanging gifts': 1.0,
#  'Clinton': 1.0,
#  'headquarters': 1.0,
#  'who': 1.0,
#  'attending feasts': 0.6666666666666666,
#  'big brother': 0.6666666666666666,
#  'is better than Donald Trump': 0.5,
#  'Hillary': 0.5,
#  'a very large company': 0.3333333333333333,
#  'there': 0.3333333333333333,
#  'The US President': 0.3333333333333333,
#  'President': 0.3333333333333333,
#  'a song': 0.3333333333333333,
#  'WrittenWork': 0.3333333333333333,
#  'PeriodicalLiterature': 0.3333333333333333,
#  'feasts': 0.3333333333333333,
#  'the Festival': 0.3333333333333333,
#  'Donald': 0.3333333333333333,
#  'Manoj': 0.3,
#  'Trump': 0.2857142857142857,
#  'Hillary Clinton': 0.2857142857142857,
#  'Biden': 0.2857142857142857,
#  'Donald Trump': 0.24444444444444444,
#  'Britney': 0.21428571428571427,
#  'also the New Year': 0.2,
#  'Joe Biden': 0.19444444444444445,
#  'three bears': 0.16666666666666666,
#  'Britney Spears': 0.16666666666666666,
#  'Work': 0.16666666666666666,
#  'Artist': 0.16666666666666666,
#  'Rinku Das': 0.16666666666666666,
#  'Rinku': 0.16666666666666666,
#  'Manoj Das': 0.15555555555555556,
#  'It': 0.14285714285714285,
#  'that': 0.1,
#  'New': 0.1,
#  'Year': 0.1,
#  'Baby One More Time': 0.08888888888888889,
#  'Time': 0.08333333333333333,
#  'person': 0.07692307692307693,
#  'natural person': 0.07692307692307693,
#  'human': 0.0761904761904762,
#  'generally a time': 0.07272727272727272,
#  'brother': 0.07272727272727272,
#  'gifts': 0.06666666666666667,
#  'Person': 0.06060606060606061,
#  'Diwali': 0.06060606060606061,
#  'IBM': 0.05454545454545454,
#  'Agent': 0.05128205128205128,
#  'the New Year': 0.044444444444444446,
#  'USA': 0.038461538461538464,
#  'Lights': 0.03571428571428571,
#  'time': 0.030303030303030304,
#  'song': 0.027777777777777776,
#  'people': 0.015151515151515152,
#  'single': 0.0,
#  'release': 0.0,
#  'Baby': 0.0,
#  'demographic profile': 0.0,
#  'One': 0.0,
#  'power of 10': 0.0,
#  'centered triangular number': 0.0,
#  'centered pentagonal number': 0.0,
#  'online magazine': 0.0,
#  'print news magazine': 0.0,
#  'magazine': 0.0,
#  'periodical': 0.0,
#  'communication medium': 0.0,
#  'literary form': 0.0,
#  'type of musical work/composition': 0.0,
#  'genre': 0.0,
#  'class': 0.0,
#  'collection_of_musical_notes': 0.0,
#  'composition_of_music': 0.0,
#  'music': 0.0,
#  'album': 0.0,
#  'Spears': 0.0,
#  'family name': 0.0,
#  'visits': 0.0,
#  'wearing new clothes': 0.0,
#  'feeding the poor': 0.0,
#  'lighting fireworks': 0.0,
#  'holiday': 0.0,
#  'festival': 0.0,
#  'recurring event': 0.0,
#  'Holiday': 0.0,
#  'abstract_concept': 0.0,
#  'arbatrary': 0.0,
#  'constant': 0.0,
#  'scholarly article': 0.0,
#  'Wikimedia list article': 0.0,
#  'going': 0.0,
#  'social_activity': 0.0,
#  'meeting': 0.0,
#  'literary work': 0.0,
#  'object': 0.0,
#  'present': 0.0,
#  'software': 0.0,
#  'clothes': 0.0,
#  'thing': 0.0,
#  'fireworks': 0.0,
#  'MusicalWork': 0.0,
#  'low_explosive': 0.0,
#  'new clothes': 0.0,
#  'Festival': 0.0,
#  'form of event': 0.0,
#  'light lamps': 0.0,
#  'their homes': 0.0,
#  'worship Godess Lakshmi': 0.0,
#  'organisms known by a particular common name': 0.0,
#  'counting unit': 0.0,
#  'alcoholics': 0.0,
#  'alergic_to_fur': 0.0,
#  'alergic_to_wheat': 0.0,
#  'lamps': 0.0,
#  'light': 0.0,
#  'electrical_device': 0.0,
#  'source_of_illumination': 0.0,
#  'homes': 0.0,
#  'castle': 0.0,
#  'comfortable_place_to_live': 0.0,
#  'house': 0.0,
#  'Godess': 0.0,
#  'painting': 0.0,
#  'Lakshmi': 0.0,
#  'Devi': 0.0,
#  'love deity': 0.0,
#  'wealth deity': 0.0,
#  'brand new clothes': 0.0,
#  'brand': 0.0,
#  'second-order class': 0.0,
#  'first-order metaclass': 0.0,
#  'fixed-order metaclass': 0.0,
#  '(meta)class': 0.0,
#  'mountain': 0.0,
#  'kind': 0.0,
#  'marker': 0.0,
#  'extremely expensive clothes': 0.0,
#  'the worst president': 0.0,
#  'federal republic': 0.0,
#  'superpower': 0.0,
#  'constitutional republic': 0.0,
#  'sovereign state': 0.0,
#  'democratic republic': 0.0,
#  'PopulatedPlace': 0.0,
#  'Place': 0.0,
#  'Country': 0.0,
#  'male given name': 0.0,
#  'president': 0.0,
#  'position': 0.0,
#  'elected_official': 0.0,
#  'goat_sucker': 0.0,
#  'head_of_government': 0.0,
#  'is better than him': 0.0,
#  'Gujratis': 0.0,
#  'a shopping spree': 0.0,
#  'ethnic group': 0.0,
#  'social group': 0.0,
#  'group of humans': 0.0,
#  'EthnicGroup': 0.0,
#  'shopping': 0.0,
#  'industry': 0.0,
#  'activity': 0.0,
#  'action': 0.0,
#  'tiring': 0.0,
#  'buying_activity': 0.0,
#  'buying': 0.0,
#  'spree': 0.0,
#  'river': 0.0,
#  'occupation': 0.0,
#  'human activity': 0.0,
#  'intemperance': 0.0,
#  'public company': 0.0,
#  'software company': 0.0,
#  'business': 0.0,
#  'enterprise': 0.0,
#  'Organisation': 0.0,
#  'Company': 0.0,
#  'company': 0.0,
#  'legal form': 0.0,
#  'type of organisation': 0.0,
#  'capitalist_institution': 0.0,
#  'legal_entity': 0.0,
#  'organization': 0.0,
#  'India': 0.0,
#  'country': 0.0,
#  'dominion of the British Empire': 0.0,
#  'We': 0.0,
#  'celebrate this festival': 0.0,
#  'great fervour': 0.0,
#  'social': 0.0,
#  'celebration': 0.0,
#  'time_period': 0.0,
#  'fervour': 0.0,
#  'Mitzvah': 0.0,
#  'musical ensemble': 0.0,
#  'public holiday': 0.0,
#  'non-working day': 0.0,
#  'modern language': 0.0,
#  'definitely endangered language': 0.0,
#  'language': 0.0,
#  'unit of time': 0.0,
#  'unit without standard conversion to SI': 0.0,
#  'UCUM derived unit': 0.0,
#  'Retailers': 0.0,
#  'this festival': 0.0,
#  'economic branch': 0.0,
#  'system': 0.0,
#  'structure': 0.0,
#  'distributor': 0.0,
#  'merchant': 0.0,
#  'the windward side': 0.0,
#  'very big island': 0.0,
#  'island': 0.0,
#  'island nation': 0.0,
#  'RecordLabel': 0.0,
#  'another_name_for_roundabout': 0.0,
#  'body_of_land': 0.0,
#  'completely': 0.0,
#  'side': 0.0,
#  'component': 0.0,
#  'perceptible object': 0.0,
#  'physical object': 0.0,
#  'physical_surface': 0.0,
#  'surface': 0.0,
#  'aspect': 0.0,
#  'had rocks': 0.0,
#  'eastern shore': 0.0,
#  'shore': 0.0,
#  'at_sea_level': 0.0,
#  'beam': 0.0,
#  'geological_formation': 0.0,
#  'rocks': 0.0,
#  'genre_of_music': 0.0,
#  'hard': 0.0,
#  'inanimate_object': 0.0,
#  'Justin': 0.0,
#  'a fight': 0.0,
#  ' unnecessarily': 0.0,
#  'fight': 0.0,
#  'boxing match': 0.0,
#  'sporting event': 0.0,
#  'entertainment event': 0.0,
#  'conflict': 0.0,
#  'dangerous_activity': 0.0,
#  'irreflexive_action': 0.0,
#  'Das': 0.0,
#  'kinship': 0.0,
#  'social relation': 0.0,
#  "another_son_of_one's_own_parents": 0.0,
#  'big_goof': 0.0,
#  'family_relationship_term': 0.0,
#  'is daughter': 0.0,
#  'Tina': 0.0,
#  'female given name': 0.0,
#  'daughter': 0.0,
#  'child': 0.0,
#  'female_offspring': 0.0,
#  'Mortgage renewal process': 0.0,
#  'end': 0.0,
#  'term': 0.0,
#  'Mortgage': 0.0,
#  'authorized_agreement': 0.0,
#  'secured_loan': 0.0,
#  'written_loan_contract': 0.0,
#  'renewal': 0.0,
#  'occurrence': 0.0,
#  'redevelopment': 0.0,
#  'urban planning': 0.0,
#  'construction': 0.0,
#  'repetition': 0.0,
#  'process': 0.0,
#  'projection_from_bone': 0.0,
#  'series_of_steps_taken': 0.0,
#  'physical_entity': 0.0,
#  'American football position': 0.0,
#  'contribution': 0.0,
#  'lineman': 0.0,
#  'piece_of_cloth': 0.0,
#  'register': 0.0,
#  'unit_of_time': 0.0,
#  'indeterminate_term': 0.0,
#  'quantity': 0.0,
#  'Mumbai': 0.0,
#  'the capital': 0.0,
#  'Maharashtra': 0.0,
#  'megacity': 0.0,
#  'big city': 0.0,
#  'million city': 0.0,
#  'state capital': 0.0,
#  'city': 0.0,
#  'City': 0.0,
#  'Settlement': 0.0,
#  'state of India': 0.0,
#  'states and union territories of India': 0.0,
#  'federated state': 0.0,
#  'capital': 0.0,
#  'largely': 0.0,
#  'principle_to_capitalism': 0.0,
#  'the financial capital': 0.0,
#  'Once upon a time': 0.0,
#  'bears': 0.0,
#  'American football team': 0.0,
#  'taxon': 0.0,
#  'group of living things': 0.0,
#  'Animal': 0.0,
#  'Eukaryote': 0.0,
#  'Species': 0.0,
#  'carnivore': 0.0,
#  'mammal': 0.0,
#  ' were married': 0.0,
#  'People': 0.0,
#  'text': 0.0,
#  'publication': 0.0,
#  'US': 0.0,
#  'album chart': 0.0,
#  'record chart': 0.0,
#  'ranked list': 0.0,
#  'Joe': 0.0,
#  'Han surname': 0.0,
#  'Thriller': 0.0,
#  'a hit album': 0.0,
#  'Michael Jackson': 0.0,
#  '1984': 0.0,
#  'fiction genre': 0.0,
#  'leap year starting on Sunday and ending on Monday': 0.0,
#  'calendar year': 0.0,
#  'leap year': 0.0,
#  'hit': 0.0,
#  'ministry-owned university': 0.0,
#  'vice-ministerial level university': 0.0,
#  'university': 0.0,
#  'sports terminology': 0.0,
#  'specialized terminology': 0.0,
#  'human communication': 0.0,
#  'joining': 0.0,
#  'murder': 0.0,
#  'success': 0.0,
#  'music release type': 0.0,
#  'music term': 0.0,
#  'technical term': 0.0,
#  'collection': 0.0,
#  'Michael': 0.0,
#  'archangel': 0.0,
#  'angel in Judaism': 0.0,
#  'Mukarrabun': 0.0,
#  'Jackson': 0.0,
#  'city of the United States': 0.0,
#  'state or insular area capital in the United States': 0.0,
#  'early 1984': 0.0,
#  'have a working prototype': 0.0,
#  'a rocket': 0.0,
#  'prototype': 0.0,
#  'model': 0.0,
#  'video_game': 0.0,
#  'rocket': 0.0,
#  'artifact': 0.0,
#  'faster_than_aeroplane': 0.0,
#  'machine': 0.0}

# %%
response = nx.clustering(G)

biggest_coefficient = sorted(response.items(), key=lambda x: x[1], reverse=True)
for character in biggest_coefficient[:10]:
    print(list(character)[:10])
# Out:
# ['exchanging gifts', 1.0]
# ['Clinton', 1.0]
# ['headquarters', 1.0]
# ['who', 1.0]
# ['attending feasts', 0.6666666666666666]
# ['big brother', 0.6666666666666666]
# ['is better than Donald Trump', 0.5]
# ['Hillary', 0.5]
# ['a very large company', 0.3333333333333333]
# ['there', 0.3333333333333333]

# %%
list(nx.connected_components(G))
# Out:
# [{' unnecessarily',
#   ' were married',
#   '(meta)class',
#   '1984',
#   'Agent',
#   'American football position',
#   'American football team',
#   'Animal',
#   'Artist',
#   'Baby',
#   'Baby One More Time',
#   'Biden',
#   'Britney',
#   'Britney Spears',
#   'City',
#   'Clinton',
#   'Company',
#   'Country',
#   'Das',
#   'Devi',
#   'Diwali',
#   'Donald',
#   'Donald Trump',
#   'EthnicGroup',
#   'Eukaryote',
#   'Festival',
#   'Godess',
#   'Gujratis',
#   'Han surname',
#   'Hillary',
#   'Hillary Clinton',
#   'Holiday',
#   'IBM',
#   'India',
#   'It',
#   'Jackson',
#   'Joe',
#   'Joe Biden',
#   'Justin',
#   'Lakshmi',
#   'Lights',
#   'Maharashtra',
#   'Manoj',
#   'Manoj Das',
#   'Michael',
#   'Michael Jackson',
#   'Mitzvah',
#   'Mortgage',
#   'Mortgage renewal process',
#   'Mukarrabun',
#   'Mumbai',
#   'MusicalWork',
#   'New',
#   'Once upon a time',
#   'One',
#   'Organisation',
#   'People',
#   'PeriodicalLiterature',
#   'Person',
#   'Place',
#   'PopulatedPlace',
#   'President',
#   'RecordLabel',
#   'Retailers',
#   'Rinku',
#   'Rinku Das',
#   'Settlement',
#   'Spears',
#   'Species',
#   'The US President',
#   'Thriller',
#   'Time',
#   'Tina',
#   'Trump',
#   'UCUM derived unit',
#   'US',
#   'USA',
#   'We',
#   'Wikimedia list article',
#   'Work',
#   'WrittenWork',
#   'Year',
#   'a fight',
#   'a hit album',
#   'a rocket',
#   'a shopping spree',
#   'a song',
#   'a very large company',
#   'abstract_concept',
#   'action',
#   'activity',
#   'album',
#   'album chart',
#   'alcoholics',
#   'alergic_to_fur',
#   'alergic_to_wheat',
#   'also the New Year',
#   'angel in Judaism',
#   'another_name_for_roundabout',
#   "another_son_of_one's_own_parents",
#   'arbatrary',
#   'archangel',
#   'artifact',
#   'aspect',
#   'at_sea_level',
#   'attending feasts',
#   'authorized_agreement',
#   'beam',
#   'bears',
#   'big brother',
#   'big city',
#   'big_goof',
#   'body_of_land',
#   'boxing match',
#   'brand',
#   'brand new clothes',
#   'brother',
#   'business',
#   'buying',
#   'buying_activity',
#   'calendar year',
#   'capital',
#   'capitalist_institution',
#   'carnivore',
#   'castle',
#   'celebrate this festival',
#   'celebration',
#   'centered pentagonal number',
#   'centered triangular number',
#   'child',
#   'city',
#   'city of the United States',
#   'class',
#   'clothes',
#   'collection',
#   'collection_of_musical_notes',
#   'comfortable_place_to_live',
#   'communication medium',
#   'company',
#   'completely',
#   'component',
#   'composition_of_music',
#   'conflict',
#   'constant',
#   'constitutional republic',
#   'construction',
#   'contribution',
#   'counting unit',
#   'country',
#   'dangerous_activity',
#   'daughter',
#   'definitely endangered language',
#   'democratic republic',
#   'demographic profile',
#   'distributor',
#   'dominion of the British Empire',
#   'early 1984',
#   'eastern shore',
#   'economic branch',
#   'elected_official',
#   'electrical_device',
#   'end',
#   'enterprise',
#   'entertainment event',
#   'ethnic group',
#   'exchanging gifts',
#   'extremely expensive clothes',
#   'family name',
#   'family_relationship_term',
#   'faster_than_aeroplane',
#   'feasts',
#   'federal republic',
#   'federated state',
#   'feeding the poor',
#   'female given name',
#   'female_offspring',
#   'fervour',
#   'festival',
#   'fiction genre',
#   'fight',
#   'fireworks',
#   'first-order metaclass',
#   'fixed-order metaclass',
#   'form of event',
#   'generally a time',
#   'genre',
#   'genre_of_music',
#   'geological_formation',
#   'gifts',
#   'goat_sucker',
#   'going',
#   'great fervour',
#   'group of humans',
#   'group of living things',
#   'had rocks',
#   'hard',
#   'have a working prototype',
#   'head_of_government',
#   'headquarters',
#   'hit',
#   'holiday',
#   'homes',
#   'house',
#   'human',
#   'human activity',
#   'human communication',
#   'inanimate_object',
#   'indeterminate_term',
#   'industry',
#   'intemperance',
#   'irreflexive_action',
#   'is better than Donald Trump',
#   'is better than him',
#   'is daughter',
#   'island',
#   'island nation',
#   'joining',
#   'kind',
#   'kinship',
#   'lamps',
#   'language',
#   'largely',
#   'leap year',
#   'leap year starting on Sunday and ending on Monday',
#   'legal form',
#   'legal_entity',
#   'light',
#   'light lamps',
#   'lighting fireworks',
#   'lineman',
#   'literary form',
#   'literary work',
#   'love deity',
#   'low_explosive',
#   'machine',
#   'magazine',
#   'male given name',
#   'mammal',
#   'marker',
#   'meeting',
#   'megacity',
#   'merchant',
#   'million city',
#   'ministry-owned university',
#   'model',
#   'modern language',
#   'mountain',
#   'murder',
#   'music',
#   'music release type',
#   'music term',
#   'musical ensemble',
#   'natural person',
#   'new clothes',
#   'non-working day',
#   'object',
#   'occupation',
#   'occurrence',
#   'online magazine',
#   'organisms known by a particular common name',
#   'organization',
#   'painting',
#   'people',
#   'perceptible object',
#   'periodical',
#   'person',
#   'physical object',
#   'physical_entity',
#   'physical_surface',
#   'piece_of_cloth',
#   'position',
#   'power of 10',
#   'present',
#   'president',
#   'principle_to_capitalism',
#   'print news magazine',
#   'process',
#   'projection_from_bone',
#   'prototype',
#   'public company',
#   'public holiday',
#   'publication',
#   'quantity',
#   'ranked list',
#   'record chart',
#   'recurring event',
#   'redevelopment',
#   'register',
#   'release',
#   'renewal',
#   'repetition',
#   'river',
#   'rocket',
#   'rocks',
#   'scholarly article',
#   'second-order class',
#   'secured_loan',
#   'series_of_steps_taken',
#   'shopping',
#   'shore',
#   'side',
#   'single',
#   'social',
#   'social group',
#   'social relation',
#   'social_activity',
#   'software',
#   'software company',
#   'song',
#   'source_of_illumination',
#   'sovereign state',
#   'specialized terminology',
#   'sporting event',
#   'sports terminology',
#   'spree',
#   'state capital',
#   'state of India',
#   'state or insular area capital in the United States',
#   'states and union territories of India',
#   'structure',
#   'success',
#   'superpower',
#   'surface',
#   'system',
#   'taxon',
#   'technical term',
#   'term',
#   'text',
#   'that',
#   'the Festival',
#   'the New Year',
#   'the capital',
#   'the financial capital',
#   'the windward side',
#   'the worst president',
#   'their homes',
#   'there',
#   'thing',
#   'this festival',
#   'three bears',
#   'time',
#   'time_period',
#   'tiring',
#   'type of musical work/composition',
#   'type of organisation',
#   'unit of time',
#   'unit without standard conversion to SI',
#   'unit_of_time',
#   'university',
#   'urban planning',
#   'very big island',
#   'vice-ministerial level university',
#   'video_game',
#   'visits',
#   'wealth deity',
#   'wearing new clothes',
#   'who',
#   'worship Godess Lakshmi',
#   'written_loan_contract'}]

# %%
nx.number_connected_components(G)
# Out:
# 1

# %%
nx.triangles(G) #RAW OUTPUT
# Out:
# {' unnecessarily': 0,
#  ' were married': 0,
#  '(meta)class': 0,
#  '1984': 0,
#  'Agent': 4,
#  'American football position': 0,
#  'American football team': 0,
#  'Animal': 0,
#  'Artist': 1,
#  'Baby': 0,
#  'Baby One More Time': 4,
#  'Biden': 6,
#  'Britney': 6,
#  'Britney Spears': 6,
#  'City': 0,
#  'Clinton': 1,
#  'Company': 0,
#  'Country': 0,
#  'Das': 0,
#  'Devi': 0,
#  'Diwali': 4,
#  'Donald': 1,
#  'Donald Trump': 11,
#  'EthnicGroup': 0,
#  'Eukaryote': 0,
#  'Festival': 0,
#  'Godess': 0,
#  'Gujratis': 0,
#  'Han surname': 0,
#  'Hillary': 3,
#  'Hillary Clinton': 8,
#  'Holiday': 0,
#  'IBM': 3,
#  'India': 0,
#  'It': 3,
#  'Jackson': 0,
#  'Joe': 0,
#  'Joe Biden': 7,
#  'Justin': 0,
#  'Lakshmi': 0,
#  'Lights': 1,
#  'Maharashtra': 0,
#  'Manoj': 3,
#  'Manoj Das': 7,
#  'Michael': 0,
#  'Michael Jackson': 0,
#  'Mitzvah': 0,
#  'Mortgage': 0,
#  'Mortgage renewal process': 0,
#  'Mukarrabun': 0,
#  'Mumbai': 0,
#  'MusicalWork': 0,
#  'New': 1,
#  'Once upon a time': 0,
#  'One': 0,
#  'Organisation': 0,
#  'People': 0,
#  'PeriodicalLiterature': 1,
#  'Person': 4,
#  'Place': 0,
#  'PopulatedPlace': 0,
#  'President': 2,
#  'RecordLabel': 0,
#  'Retailers': 0,
#  'Rinku': 1,
#  'Rinku Das': 1,
#  'Settlement': 0,
#  'Spears': 0,
#  'Species': 0,
#  'The US President': 1,
#  'Thriller': 0,
#  'Time': 3,
#  'Tina': 0,
#  'Trump': 6,
#  'UCUM derived unit': 0,
#  'US': 0,
#  'USA': 3,
#  'We': 0,
#  'Wikimedia list article': 0,
#  'Work': 1,
#  'WrittenWork': 1,
#  'Year': 1,
#  'a fight': 0,
#  'a hit album': 0,
#  'a rocket': 0,
#  'a shopping spree': 0,
#  'a song': 1,
#  'a very large company': 1,
#  'abstract_concept': 0,
#  'action': 0,
#  'activity': 0,
#  'album': 0,
#  'album chart': 0,
#  'alcoholics': 0,
#  'alergic_to_fur': 0,
#  'alergic_to_wheat': 0,
#  'also the New Year': 2,
#  'angel in Judaism': 0,
#  'another_name_for_roundabout': 0,
#  "another_son_of_one's_own_parents": 0,
#  'arbatrary': 0,
#  'archangel': 0,
#  'artifact': 0,
#  'aspect': 0,
#  'at_sea_level': 0,
#  'attending feasts': 2,
#  'authorized_agreement': 0,
#  'beam': 0,
#  'bears': 0,
#  'big brother': 2,
#  'big city': 0,
#  'big_goof': 0,
#  'body_of_land': 0,
#  'boxing match': 0,
#  'brand': 0,
#  'brand new clothes': 0,
#  'brother': 4,
#  'business': 0,
#  'buying': 0,
#  'buying_activity': 0,
#  'calendar year': 0,
#  'capital': 0,
#  'capitalist_institution': 0,
#  'carnivore': 0,
#  'castle': 0,
#  'celebrate this festival': 0,
#  'celebration': 0,
#  'centered pentagonal number': 0,
#  'centered triangular number': 0,
#  'child': 0,
#  'city': 0,
#  'city of the United States': 0,
#  'class': 0,
#  'clothes': 0,
#  'collection': 0,
#  'collection_of_musical_notes': 0,
#  'comfortable_place_to_live': 0,
#  'communication medium': 0,
#  'company': 0,
#  'completely': 0,
#  'component': 0,
#  'composition_of_music': 0,
#  'conflict': 0,
#  'constant': 0,
#  'constitutional republic': 0,
#  'construction': 0,
#  'contribution': 0,
#  'counting unit': 0,
#  'country': 0,
#  'dangerous_activity': 0,
#  'daughter': 0,
#  'definitely endangered language': 0,
#  'democratic republic': 0,
#  'demographic profile': 0,
#  'distributor': 0,
#  'dominion of the British Empire': 0,
#  'early 1984': 0,
#  'eastern shore': 0,
#  'economic branch': 0,
#  'elected_official': 0,
#  'electrical_device': 0,
#  'end': 0,
#  'enterprise': 0,
#  'entertainment event': 0,
#  'ethnic group': 0,
#  'exchanging gifts': 1,
#  'extremely expensive clothes': 0,
#  'family name': 0,
#  'family_relationship_term': 0,
#  'faster_than_aeroplane': 0,
#  'feasts': 1,
#  'federal republic': 0,
#  'federated state': 0,
#  'feeding the poor': 0,
#  'female given name': 0,
#  'female_offspring': 0,
#  'fervour': 0,
#  'festival': 0,
#  'fiction genre': 0,
#  'fight': 0,
#  'fireworks': 0,
#  'first-order metaclass': 0,
#  'fixed-order metaclass': 0,
#  'form of event': 0,
#  'generally a time': 4,
#  'genre': 0,
#  'genre_of_music': 0,
#  'geological_formation': 0,
#  'gifts': 1,
#  'goat_sucker': 0,
#  'going': 0,
#  'great fervour': 0,
#  'group of humans': 0,
#  'group of living things': 0,
#  'had rocks': 0,
#  'hard': 0,
#  'have a working prototype': 0,
#  'head_of_government': 0,
#  'headquarters': 1,
#  'hit': 0,
#  'holiday': 0,
#  'homes': 0,
#  'house': 0,
#  'human': 8,
#  'human activity': 0,
#  'human communication': 0,
#  'inanimate_object': 0,
#  'indeterminate_term': 0,
#  'industry': 0,
#  'intemperance': 0,
#  'irreflexive_action': 0,
#  'is better than Donald Trump': 3,
#  'is better than him': 0,
#  'is daughter': 0,
#  'island': 0,
#  'island nation': 0,
#  'joining': 0,
#  'kind': 0,
#  'kinship': 0,
#  'lamps': 0,
#  'language': 0,
#  'largely': 0,
#  'leap year': 0,
#  'leap year starting on Sunday and ending on Monday': 0,
#  'legal form': 0,
#  'legal_entity': 0,
#  'light': 0,
#  'light lamps': 0,
#  'lighting fireworks': 0,
#  'lineman': 0,
#  'literary form': 0,
#  'literary work': 0,
#  'love deity': 0,
#  'low_explosive': 0,
#  'machine': 0,
#  'magazine': 0,
#  'male given name': 0,
#  'mammal': 0,
#  'marker': 0,
#  'meeting': 0,
#  'megacity': 0,
#  'merchant': 0,
#  'million city': 0,
#  'ministry-owned university': 0,
#  'model': 0,
#  'modern language': 0,
#  'mountain': 0,
#  'murder': 0,
#  'music': 0,
#  'music release type': 0,
#  'music term': 0,
#  'musical ensemble': 0,
#  'natural person': 6,
#  'new clothes': 0,
#  'non-working day': 0,
#  'object': 0,
#  'occupation': 0,
#  'occurrence': 0,
#  'online magazine': 0,
#  'organisms known by a particular common name': 0,
#  'organization': 0,
#  'painting': 0,
#  'people': 1,
#  'perceptible object': 0,
#  'periodical': 0,
#  'person': 6,
#  'physical object': 0,
#  'physical_entity': 0,
#  'physical_surface': 0,
#  'piece_of_cloth': 0,
#  'position': 0,
#  'power of 10': 0,
#  'present': 0,
#  'president': 0,
#  'principle_to_capitalism': 0,
#  'print news magazine': 0,
#  'process': 0,
#  'projection_from_bone': 0,
#  'prototype': 0,
#  'public company': 0,
#  'public holiday': 0,
#  'publication': 0,
#  'quantity': 0,
#  'ranked list': 0,
#  'record chart': 0,
#  'recurring event': 0,
#  'redevelopment': 0,
#  'register': 0,
#  'release': 0,
#  'renewal': 0,
#  'repetition': 0,
#  'river': 0,
#  'rocket': 0,
#  'rocks': 0,
#  'scholarly article': 0,
#  'second-order class': 0,
#  'secured_loan': 0,
#  'series_of_steps_taken': 0,
#  'shopping': 0,
#  'shore': 0,
#  'side': 0,
#  'single': 0,
#  'social': 0,
#  'social group': 0,
#  'social relation': 0,
#  'social_activity': 0,
#  'software': 0,
#  'software company': 0,
#  'song': 1,
#  'source_of_illumination': 0,
#  'sovereign state': 0,
#  'specialized terminology': 0,
#  'sporting event': 0,
#  'sports terminology': 0,
#  'spree': 0,
#  'state capital': 0,
#  'state of India': 0,
#  'state or insular area capital in the United States': 0,
#  'states and union territories of India': 0,
#  'structure': 0,
#  'success': 0,
#  'superpower': 0,
#  'surface': 0,
#  'system': 0,
#  'taxon': 0,
#  'technical term': 0,
#  'term': 0,
#  'text': 0,
#  'that': 1,
#  'the Festival': 1,
#  'the New Year': 2,
#  'the capital': 0,
#  'the financial capital': 0,
#  'the windward side': 0,
#  'the worst president': 0,
#  'their homes': 0,
#  'there': 1,
#  'thing': 0,
#  'this festival': 0,
#  'three bears': 1,
#  'time': 2,
#  'time_period': 0,
#  'tiring': 0,
#  'type of musical work/composition': 0,
#  'type of organisation': 0,
#  'unit of time': 0,
#  'unit without standard conversion to SI': 0,
#  'unit_of_time': 0,
#  'university': 0,
#  'urban planning': 0,
#  'very big island': 0,
#  'vice-ministerial level university': 0,
#  'video_game': 0,
#  'visits': 0,
#  'wealth deity': 0,
#  'wearing new clothes': 0,
#  'who': 1,
#  'worship Godess Lakshmi': 0,
#  'written_loan_contract': 0}

# %% [markdown]
# ## 3. Path Finding Algorithms

# %% [markdown]
# Let's find the distance between two characters

# %%
# Shortest path
nx.shortest_path(G, source="Tyrion-Lannister", target="Hodor")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /var/folders/w3/l510_xxs1jsdsqg4b4z7ycbw0000gn/T/ipykernel_34940/1991396960.py in <module>
#       1 # Shortest path
# ----> 2 nx.shortest_path(G, source="Tyrion-Lannister", target="Hodor")
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/nxneo4j/path_finding.py in shortest_path(G, source, target)
#      70
#      71 def shortest_path(G,source, target):
# ---> 72     return shortest_weighted_path(G,source, target, weight='')
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/nxneo4j/path_finding.py in shortest_weighted_path(G, source, target, weight)
#      66                 params["weight"] = weight
#      67
# ---> 68                 paths = [row["node"] for row in session.run(query, params)]
#      69     return paths
#      70
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/work/simple.py in run(self, query, parameters, **kwparameters)
#     213             self._result_error
#     214         )
# --> 215         self._autoResult._run(
#     216             query, parameters, self._config.database,
#     217             self._config.impersonated_user, self._config.default_access_mode,
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/work/result.py in _run(self, query, parameters, db, imp_user, access_mode, bookmarks, **kwparameters)
#     112         self._pull()
#     113         self._connection.send_all()
# --> 114         self._attach()
#     115
#     116     def _pull(self):
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/work/result.py in _attach(self)
#     201         if self._closed is False:
#     202             while self._attached is False:
# --> 203                 self._connection.fetch_message()
#     204
#     205     def _buffer(self, n=None):
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/io/_common.py in inner(*args, **kwargs)
#     168             def inner(*args, **kwargs):
#     169                 try:
# --> 170                     func(*args, **kwargs)
#     171                 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     172                     self.__on_error(exc)
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/io/_bolt4.py in fetch_message(self)
#     307             self._server_state_manager.state = ServerStates.FAILED
#     308             try:
# --> 309                 response.on_failure(summary_metadata or {})
#     310             except (ServiceUnavailable, DatabaseUnavailable):
#     311                 if self.pool:
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/io/_common.py in on_failure(self, metadata)
#     226         if callable(handler):
#     227             handler()
# --> 228         raise Neo4jError.hydrate(**metadata)
#     229
#     230     def on_ignored(self, metadata=None):
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureNotFound} {message: There is no procedure with the name `gds.alpha.shortestPath.stream` registered for this database instance. Please ensure you've spelled the procedure name correctly and that the procedure is properly deployed.}

# %%
# Shortest weighted path
nx.shortest_weighted_path(G, source="Tyrion-Lannister", target="Hodor",weight='weight')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /var/folders/w3/l510_xxs1jsdsqg4b4z7ycbw0000gn/T/ipykernel_34940/1337197465.py in <module>
#       1 # Shortest weighted path
# ----> 2 nx.shortest_weighted_path(G, source="Tyrion-Lannister", target="Hodor",weight='weight')
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/nxneo4j/path_finding.py in shortest_weighted_path(G, source, target, weight)
#      66                 params["weight"] = weight
#      67
# ---> 68                 paths = [row["node"] for row in session.run(query, params)]
#      69     return paths
#      70
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/work/simple.py in run(self, query, parameters, **kwparameters)
#     213             self._result_error
#     214         )
# --> 215         self._autoResult._run(
#     216             query, parameters, self._config.database,
#     217             self._config.impersonated_user, self._config.default_access_mode,
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/work/result.py in _run(self, query, parameters, db, imp_user, access_mode, bookmarks, **kwparameters)
#     112         self._pull()
#     113         self._connection.send_all()
# --> 114         self._attach()
#     115
#     116     def _pull(self):
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/work/result.py in _attach(self)
#     201         if self._closed is False:
#     202             while self._attached is False:
# --> 203                 self._connection.fetch_message()
#     204
#     205     def _buffer(self, n=None):
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/io/_common.py in inner(*args, **kwargs)
#     168             def inner(*args, **kwargs):
#     169                 try:
# --> 170                     func(*args, **kwargs)
#     171                 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     172                     self.__on_error(exc)
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/io/_bolt4.py in fetch_message(self)
#     307             self._server_state_manager.state = ServerStates.FAILED
#     308             try:
# --> 309                 response.on_failure(summary_metadata or {})
#     310             except (ServiceUnavailable, DatabaseUnavailable):
#     311                 if self.pool:
#
# ~/miniforge3/envs/py38_env/lib/python3.8/site-packages/neo4j/io/_common.py in on_failure(self, metadata)
#     226         if callable(handler):
#     227             handler()
# --> 228         raise Neo4jError.hydrate(**metadata)
#     229
#     230     def on_ignored(self, metadata=None):
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureNotFound} {message: There is no procedure with the name `gds.alpha.shortestPath.stream` registered for this database instance. Please ensure you've spelled the procedure name correctly and that the procedure is properly deployed.}

# %%
G.identifier_property = 'name'
